# %% [markdown]
# # Imports

# %%
from math import ceil
from time import sleep
from random import randint
from bs4 import BeautifulSoup


from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager

import pandas as pd
import numpy as np
import requests
import json
import pickle

from scraper import display_all

# %% [markdown]
# # Exp

# %%
with open('data/filled_selected_campaigns.pkl', 'rb') as f:
    campaigns = pickle.load(f)

# %%
res= []
for c in campaigns:
    if c.hrp > 1000:
        print(c.link)
# Out:
# https://www.kisskissbankbank.com/fr/projects/paroles-de-conflits
# https://www.kisskissbankbank.com/fr/projects/une-medaille-pour-la-paix
# https://www.kisskissbankbank.com/fr/projects/mata-ganga-orchestra-tour-2013
# https://www.kisskissbankbank.com/fr/projects/fumer-tue--2
# https://www.kisskissbankbank.com/fr/projects/frigos-a-nu
# https://www.kisskissbankbank.com/fr/projects/le-syndrome-du-bernard-l-hermite
# https://www.kisskissbankbank.com/fr/projects/pentes-douces-roman-50-texte-50-photo
# https://www.kisskissbankbank.com/fr/projects/le-retour-du-train
# https://www.kisskissbankbank.com/fr/projects/kesaj-tchave-les-enfants-de-la-fee
# https://www.kisskissbankbank.com/fr/projects/creation-de-la-librairie-la-boussole
# https://www.kisskissbankbank.com/fr/projects/visiter-l-afrique
# https://www.kisskissbankbank.com/fr/projects/georges
# https://www.kisskissbankbank.com/fr/projects/the-place-to-bio-l-appli-mobile-des-restos-engages
# https://www.kisskissbankbank.com/fr/projects/neptumium-ratons-spectacle-cirque-hiphop
# https://www.kisskissbankbank.com/fr/projects/24h01
# https://www.kisskissbankbank.com/fr/projects/sortie-de-l-album-the-shine-the-elementz-par-king-lee--2
# https://www.kisskissbankbank.com/fr/projects/voir-ca-ca-voir-vincent-corpet
# https://www.kisskissbankbank.com/fr/projects/startuplions
# https://www.kisskissbankbank.com/fr/projects/le-geoptimiste-la-chasse-aux-tresors-vivants
# https://www.kisskissbankbank.com/fr/projects/demain-si-dieu-veut
# https://www.kisskissbankbank.com/fr/projects/les-gueules-cassees
# https://www.kisskissbankbank.com/fr/projects/what-gavdos-quoi
# https://www.kisskissbankbank.com/fr/projects/premier-mini-album-de-grande-ourse
# https://www.kisskissbankbank.com/fr/projects/cyril-contre-goliath
# https://www.kisskissbankbank.com/fr/projects/les-lapidiales--2
# https://www.kisskissbankbank.com/fr/projects/du-loukoum-au-beton
# https://www.kisskissbankbank.com/fr/projects/montparnasse-nouvel-album-studio
# https://www.kisskissbankbank.com/fr/projects/comment-eclairer-votre-interieur-le-disque-du-ramon-pipin-band
# https://www.kisskissbankbank.com/fr/projects/quidditch-aidez-la-france-a-devenir-championne-du-monde
# https://www.kisskissbankbank.com/fr/projects/jean-et-beatrice--3
# https://www.kisskissbankbank.com/fr/projects/entreprenez-votre-vie
# https://www.kisskissbankbank.com/fr/projects/enregistrement-du-nouvel-album-au-feel-du-temps-la-malmaison
# https://www.kisskissbankbank.com/fr/projects/boutique-atelier-nathalie-grelier
# https://www.kisskissbankbank.com/fr/projects/too-good-to-go
# https://www.kisskissbankbank.com/fr/projects/krut-herbes-du-frais-du-froid-du-bio
# https://www.kisskissbankbank.com/fr/projects/ma-mere-et-mon-pere-annem-ve-babam-en-dvd-et-en-anglais
# https://www.kisskissbankbank.com/fr/projects/blues-chocolat-un-spectacle-musico-culinaire-gourmand-en-avignon
# https://www.kisskissbankbank.com/fr/projects/peripleties-voyages-reportages--2
# https://www.kisskissbankbank.com/fr/projects/peepshow-dans-les-alpes
# https://www.kisskissbankbank.com/fr/projects/l-arbre-a-cuire
# https://www.kisskissbankbank.com/fr/projects/revealing-the-shadows-portraits-of-the-new-parisians
# https://www.kisskissbankbank.com/fr/projects/navlab
# https://www.kisskissbankbank.com/fr/projects/the-tattoorialist-le-tour-de-france-des-tatoues

# %%
df = pd.read_csv('data/output/macro.csv', sep=';')

# %%
df.describe()

# %%
df.describe()

# %%
df.describe()
# Out:
#        Unnamed: 0  nb_contrib  completion_rate  comments   num_pers  \
# count   51.000000   51.000000        51.000000      51.0  51.000000
# mean    25.000000  139.823529       153.862745       0.0   1.294118
# std     14.866069  137.731871        92.853006       0.0   2.247613
# min      0.000000   20.000000       100.000000       0.0   0.000000
# 25%     12.500000   61.500000       104.500000       0.0   0.000000
# 50%     25.000000  106.000000       120.000000       0.0   0.000000
# 75%     37.500000  172.000000       170.000000       0.0   2.000000
# max     50.000000  879.000000       703.000000       0.0  14.000000
#
#         num_info     num_don    mean_don  num_jump_1  num_jump_mean  \
# count  51.000000   51.000000   51.000000   51.000000      51.000000
# mean    2.176471  145.450980   72.847845  132.274510      44.549020
# std     2.635951  139.388854  116.392631  129.339411      60.802406
# min     0.000000   20.000000   25.223958   16.000000       5.000000
# 25%     0.000000   64.500000   40.703871   59.500000      19.000000
# 50%     1.000000  110.000000   51.336364  100.000000      28.000000
# 75%     3.000000  176.500000   72.352583  164.500000      53.000000
# max    12.000000  881.000000  872.850000  843.000000     420.000000
#
#         nb_actus  duration  nb_max_reward_lvl  facebook  nb_likes_fb  \
# count  51.000000      51.0                0.0       0.0          0.0
# mean    3.470588      60.0                NaN       NaN          NaN
# std     3.613048       0.0                NaN       NaN          NaN
# min     0.000000      60.0                NaN       NaN          NaN
# 25%     0.500000      60.0                NaN       NaN          NaN
# 50%     2.000000      60.0                NaN       NaN          NaN
# 75%     6.000000      60.0                NaN       NaN          NaN
# max    15.000000      60.0                NaN       NaN          NaN
#
#        other_projects
# count             0.0
# mean              NaN
# std               NaN
# min               NaN
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               NaN
